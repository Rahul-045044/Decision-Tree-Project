# %% [markdown]
# #**Report**
#
# #"Harmonizing Tunes: Leveraging Classification Algorithms for Music Recommendation Systems
#
# #Objectives
#
# 1.1. Classify music tracks into distinct clusters representing emotional characteristics such as Versatile and Balanced, Energetic and Dynamic, and Dynamic and Expressive using supervised learning algorithms.
#
# 1.2. Determine the optimal classification model for accurately assigning music tracks to predefined emotional clusters.
#
# 1.3. Identify the pivotal features and their respective thresholds crucial for precise classification of music tracks.
#
# #2. Description of Data
# The Music Recommendation System dataset is a collection of attributes related to various musical tracks. This dataset serves as the foundation for building a music recommendation system, which is a crucial component of modern digital music platforms.
#
# 2.1. Data Source, Size, Shape
# 2.1.1 Data Source
# The source of data is kaggle. - Website Link - https://www.kaggle.com/code/vatsalmavani/music-recommendation-system-using-spotify-dataset
#
# ##2.1.2 Data Size
# The data is of 28 MB
#
# ##2.1.3 Data Shape
# The data contains 170654 Rows in total and 20 Columns in total.
#
# ##2.2. Description of Variables
# The dataset includes the following index, categorical and non categorical columns:
#
# -- Index Variable: 'id'
#
# -- Categorical Variables: 'artists', 'explicit','key','mode','name','release_date','year', 'cluster number'.
#
# --Nominal: 'artists', 'explicit','name','release_date'.
#
# --Ordinal: 'year','key','mode'.
#
# -- Non Categorical Variables: 'duration_ms','tempo', 'loudness', 'danceability', 'instrumentalness', 'liveness', 'speechiness', 'valence'.
#
# ##Dataset Description:
# Valence:
# Valence represents a measure of the musical positiveness conveyed by a track, ranging from 0 to 1. A value closer to 1 indicates a more positive emotional tone, while a value closer to 0 represents a less positive tone.
#
# Year:
# Year denotes the release year of the track, providing temporal information about the music's historical context and evolution over time.
#
# Acousticness:
# Acousticness quantifies the acoustic characteristics of the track on a scale from 0 to 1. A value of 0 suggests a predominantly electronic or synthesized sound, while a value of 1 indicates a purely acoustic recording.
#
# Danceability:
# Danceability measures how suitable a track is for dancing, ranging from 0 to 1. Higher values imply tracks with rhythms and beats conducive to dancing.
#
# Duration_ms:
# Duration_ms specifies the duration of the track in milliseconds, providing insight into the length of the musical composition.
#
# Energy:
# Energy reflects the intensity and vigor of the track's musical elements, ranging from 0 to 1. Higher values indicate more energetic and lively compositions.
#
# Instrumentalness:
# Instrumentalness quantifies the likelihood that the track contains no vocals, ranging from 0 to 1. A higher value suggests a higher probability of instrumental-only compositions.
#
# Liveness:
# Liveness measures the presence of a live audience in the recording, with values ranging from 0 to 1. A higher value indicates a higher probability of a live performance.
#
# Loudness:
# Loudness denotes the overall loudness of the track in decibels (dB), providing information about its volume and intensity.
#
# Popularity:
# Popularity indicates the popularity of the track, reflecting its reception and engagement among listeners.
#
# Speechiness:
# Speechiness measures the presence of spoken words in the track, ranging from 0 to 1. Higher values indicate tracks with more spoken-word elements, such as podcasts or spoken-word performances.
#
# Tempo:
# Tempo represents the speed or pace of the track in beats per minute (BPM), providing information about its rhythmic structure and tempo.
#
# Cluster number: cluster 0 - Versatile and Balanced, cluster 1-  Energetic and Dynamic, cluster 2-  Dynamic and Expressive.
#
# --artists and name are calling variable whereas year and release_date are not important for analysis therefore these variables are droped.
# #2.3. Descriptive Statistics
# ##2.3.1. Descriptive Statistics: Categorical Variables or Features
# For Descriptive Statistics of Categorical Variables refer to cell 14
#
# ##2.3.2. Descriptive Statistics: Non-Categorical Variables or Features
# For Descriptive Statistics of Non - Categorical Variables refer to cell 16
#
# #3. Analysis of Data
# ##3.1. Data Pre-Processing
# ##3.1.1. Missing Data Statistics and Treatment
# Field-wise:
# There are no missing values in any of the fields. Each column in the dataset has non-null values, indicating that there are no missing data points for any variable.
#
# Record-wise:
# Out of the 170,653 total records:
#
# There are no missing records; all records have complete data.
#
# Missing Data Treatment:
# Since there are no missing values in the dataset, no treatment is required for missing data.
#
# Missing Data Exclusion:
# As there are no missing values, there is no need for exclusion based on missing data.
#
# #3.1.2. Numerical Encoding of Categorical Variables or Features
# 1.Given that the dataset contains both nominal and ordinal categorical variables, we utilize Ordinal encoding to convert them into numerical representations.
#
# 2.Ordinal Encoding: This technique assigns a distinct numerical label to each category within a categorical variable.
#
# #3.1.3. Outlier Statistics and Treatment
# Outlier Detection:
# The presence of outliers in the dataset is determined through the utilization of box plots, providing a visual inspection of potential extreme values.
#
# Outliers are identified within specific columns, namely 'danceability', 'instrumentalness', 'liveness', 'speechiness', 'loudness', 'tempo', and 'duration_ms'.
#
# Outlier Treatment:
# Normalization using Min-Max Scaler: Normalization using Min-Max Scaler transforms the features by scaling them to a specified range, typically between 0 and 1, preserving the relative distances between data points. The variables on which normalization is performed are 'danceability', 'instrumentalness', 'liveness', 'speechiness', 'loudness', 'tempo', and 'duration_ms'.
#
# #3.1.4. Data Bifurcation: Training & Testing Sets
# The dataset is divided into two distinct subsets: training and testing datasets
# using stratified sampling.
#
# #Data Analysis:
#
# ###Decision Tree Model Rule:
# The tree starts by splitting the data based on the mode_y feature, which likely represents a binary mode indicator (e.g., major or minor key).
#
# If mode_y is less than or equal to 0.50, the left branch is taken; otherwise, the right branch is followed. Left Branch (mode_y <= 0.50):
#
# 1.1 If the acousticness feature is less than or equal to 0.48, further splitting occurs based on the speechiness_mn feature:
#
# 1.1.1 If speechiness_mn is less than or equal to 0.92, the class is assigned as 2 (likely representing the Dynamic and Expressive cluster):
#
# 1.1.2 If speechiness_mn is greater than 0.92, the class is assigned as 2.
#
# 1.2. If the acousticness feature is greater than 0.48, further splitting occurs based on the speechiness_mn feature:
#
# 1.2.1 If speechiness_mn is less than or equal to 0.87, the class is assigned as 0 (likely representing the Versatile and Balanced cluster).
#
# 1.2.2 If speechiness_mn is greater than 0.87, the class is assigned as 2.
#
# Right Branch (mode_y > 0.50):
#
# 2.1 If explicit_y is less than or equal to 0.50, further splitting occurs based on the duration_ms_mn feature.
#
# 2.1.1 If duration_ms_mn is less than or equal to 0.04, the class is assigned as 1 (likely representing the Energetic and Dynamic cluster).
#
# 2.1.2 If duration_ms_mn is greater than 0.04, the class is assigned as 1.
#
# 2.2 If explicit_y is greater than 0.50, further splitting occurs based on the loudness_mn feature. 2.2.1 If loudness_mn is less than or equal to 0.72, the class is assigned as 1.
#
# 2.2.2 If loudness_mn is greater than 0.72, the class is assigned as 1.
#
#
# ---Columns: Represent the categories the model predicted (recommended songs).
#
# For instance, in the first row (Actual Category 0): The model correctly recommended 1794 songs that belong to category 0. It incorrectly recommended 8051 songs as category 1 and 1937 songs as category 2.
#
# Accuracy: The overall accuracy of the model (39%) is moderate. It correctly recommended only 39% of the songs.
#
# Precision: This tells you the accuracy of the model's recommendations for each category.
#
# A precision of 0.39 for all categories indicates that out of all songs recommended, only around 39% were truly in the correct category based on the actual labels. There were many false positives (recommended but not truly belonging to the category).
#
# Recall: This tells you how well the model identified songs that belong to each actual category.
#
# A recall of 0.15 for category 0 means the model captured only 15% of all songs that actually belong to category 0. It missed many relevant songs (false negatives).
#
# Recall for category 1 (0.78) is significantly higher, suggesting the model did well at identifying songs in this category.
#
# Recall for category 2 (0.22) is also low, indicating the model missed many songs that truly belong to category 2.
#
# F1-score: This combines precision and recall into a single metric. A score closer to 1 indicates better performance. The F1-scores here are generally low, reflecting limitations in the model's ability to recommend across all categories.
#
# F1 score for category 1 is 0.22, category 2 is 0.52 and for category 3 is 0.28.
#
# Macro vs. Weighted Average:
#
# The macro-average treats all categories equally, showing a generally low performance (around 0.40). The weighted-average considers the number of songs in each category. It's similar to the macro-average here because the class distribution might be relatively balanced.
#
# ###Variable or Feature Analysis
#
# List of relevant features:
#
# mode_y: This feature has the highest importance score of 0.62.
#
# acousticness: With an importance score of 0.14, this feature is also important but less so than the mode_y.
#
# speechiness_mn: This feature has an importance score of 0.11.
#
# explicit_y: This feature has an importance score of 0.11.
#
# loudness_mn and duration_ms_mn: Both these features has an importance score of 0.03
#
# List of Non-relevant features:
#
# The initial analysis identified the musical key as a very influential factor (importance score of 1) in the model's recommendations.Due to high importance, we decided to remove the key feature -'key'.
#
# Our concern was overfitting. Overfitting occurs when a model becomes overly reliant on a single feature, in this case, the key, to make predictions. This dependence can hinder the model's ability to learn from other important aspects of the music, potentially leading to poor performance on new, unseen songs.
#
# valence, energy, danceability_mn, instrumentalness_mn, liveness_mn, popularity_mn, tempo_mn has 0 feature importance.
#
# Runtime of the program is 81.31454253196716
# Memory usage difference: 20.453125 MB
#
# ##SVM
# Columns (0, 1, 2): Represent the categories the model predicted (recommended songs). For instance, in the first row (Actual Category 0): The model correctly recommended 3627 songs that belong to category 0. It incorrectly recommended 8051 songs as category 1 and 104 songs as category 2. Precision, Recall, F1-Score, Support: These metrics evaluate the model's performance.
#
# Precision:
#
# This tells you the accuracy of the model's recommendations for each category.
#
# A precision of 0.38 for category 0 means that out of all songs recommended as category 0, only 38% were truly category 0 based on the actual labels. There were many false positives (recommended as 0 but actually 1 or 2). Precision for category 1 (0.39) is similar, and precision for category 2 (0.53) is higher, but they all indicate some misclassifications.
#
# Recall:
#
# This tells you how well the model identified songs that belong to each actual category.
#
# A recall of 0.31 for category 0 means the model captured only 31% of all songs that actually belong to category 0. It missed many relevant songs (false negatives). Recall for category 1 (0.78) is significantly higher, suggesting the model did well at identifying songs in this category. However, the recall for category 2 (0.02) is very low, indicating the model rarely recommended songs that truly belong to category 2.
#
# F1-score:
#
# This combines precision and recall into a single metric. A score closer to 1 indicates better performance. The F1-scores here are generally low, reflecting limitations in the model's ability to recommend across all categories.
#
# Accuracy:
#
# The overall accuracy of the model (39%) is moderate. It correctly recommended only 39% of the songs.
#
# Macro vs. Weighted Average:
#
# The macro-average treats all categories equally, showing a generally low performance (around 0.43). The weighted-average considers the number of songs in each category. It's similar to the macro-average here because the class distribution might be relatively balanced.
#
# Runtime of the program is 1666.6551585197449
# Memory usage difference: 260.95703125 MB
# ##KNN
#
# when n_neighbours = 5
#
# Accuracy : The KNN model demonstrates an accuracy of 38%.
#
# Precision :
#
# This tells you the accuracy of the model's predictions for each class level.
#
# A precision of 0.37 for class 0 means that out of all instances predicted as 0, only 37% were truly category 0 based on actual labels. There were many false positives (predicted 0 but actually 1 or 2). Precision for class 1 (0.40) and 2 (0.36) is slightly better, but still indicates misclassifications.
#
# The macro-average precision of 0.38 suggests a pretty bad model's predictions, considering all classes equally.
#
# Recall :
#
# The macro-average recall of 0.37 indicates the model's ability to capture true positive instances across all classes, giving equal weight to each class. It is representing not awesome but that will work.
#
# The weighted-average recall of 0.56 suggests a slightly better recall compared to the macro-average, considering the distribution of instances in each class.
#
# This tells you how well the model identified severity of each class for music recommendation.
#
# A recall of 0.50 for class 0 means the model captured 50% of all actual instances where the music or song recommended.
#
# The macro-average recall of 0.37 while the weighted average is 0.38.
#
# F1-score :
#
# The macro-average F1-score of 0.37 that their is a room for improvement.
#
# The weighted-average F1-score of 0.37 ,suggests a similar performance of the model in predicting music recommendation categories.
#
# As the number of neighbors (n_neighbours) increases, the accuracy was as follows:
#
# When k=7, the accuracy is 0.37.
#
# When k=9, the accuracy improves to 0.37.
#
# At k=11, the accuracy reach 0.38.
#
# Subsequently, at k=13 and k=15, the accuracy went to 0.37
#
# Macro vs. Weighted Average:
#
# The macro-average treats all severity levels equally, showing a generally low performance (around 0.38). The weighted-average considers the number of earthquakes in each category. It's similar to the macro-average here because the class distribution might be relatively balanced.
#
# Runtime of the program is 75.11660265922546
# Memory usage difference: 0.0 MB
#
# ##Logistic Regression
#
# Accuracy : This is the overall accuracy of the model, meaning the percentage of instances it classified correctly across all categories. In this case, it's 39%.
#
# Precision :
#
# This tells us how many of the predictions the model made for a specific class (e.g., class 0) were actually correct. For example, a precision of 0.38 for class 0 means out of all the instances the model predicted as class 0, only 38% were truly category 0 based on the actual labels, 39% for category 1 and 43% for category 2.
#
# The macro-average precision of 0.40 suggests a pretty bad model's predictions, considering all classes equally.
#
# Recall :
#
# This tells us how many of the actual instances in a specific class (e.g., class 0) did the model predict correctly. For instance, a recall of 0.25 for class 0 means out of all the actual class 0 instances, the model only predicted 25% of them correctly, class 1 predicted 76% correctly and class 2 predicted 12% correctly.
#
# The macro-average recall of 0.36 represents the pretty bad model.
#
# F1-Score
#
# This is a harmonic mean that combines precision and recall into a single metric. A score closer to 1 indicates better performance. The macro-average F1-score of 0.33 represents the pretty bad model. There is a need for improvement.
#
# The weighted-average F1-score of 0.34 representing an average score almost similar to macro average
#
# Runtime of the program is 39.91530442237854
# Memory usage difference: 4.15234375 MB
#
# #Results:
#
# ![Model Comparision.png](data:image/png;base64,...)
#
# --Overall Performance: All models have similar overall performance based on the macro-average metrics and accuracy. Their macro F1-scores range from 0.30 to 0.37, indicating a moderate ability to balance precision and recall across all categories. Their accuracy also falls within a narrow range (0.38 - 0.39).
#
# --Macro F1-Score: The SVM model still has the highest macro F1-score (0.30), suggesting it might strike a slightly better balance between precision and recall on average.
#
# --Accuracy and KNN: Interestingly, even though KNN has a similar macro F1-score to Decision Tree and Logistic Regression, its accuracy is slightly lower (0.38 compared to 0.39 for the others). This could indicate that KNN might be making more consistent but slightly less accurate predictions across categories.
#
# --Similar Performance: Decision Tree, Logistic Regression, and KNN remain very close in terms of macro-average metrics and accuracy, making it difficult to definitively choose a winner without looking at individual class performance.
#
# List of Relevant features:
#
# mode_y, acousticness, speechiness_mn, explicit_y, loudness_mn and duration_ms_mn
#
# List of Non-relevant features: key
#
# Feature of 0 importance:
#
# valence, energy, danceability_mn, instrumentalness_mn, liveness_mn, popularity_mn, tempo_mn.
#
# #Managerial Implications
#
# Appropriate Model:
# Decision Tree
#
# Managerial Insights:
# 1. Personalization based on genre and mood:
#
# We can classify songs based on features like valence (mood) and acousticness (instrumentation) to create genre-specific recommendations.
# For instance, users who liked "Billetes Azules" (high valence, low acousticness) might enjoy similar high-energy Latin music.
#
# 2. Targeting specific user segments:
#
# By classifying songs based on features like artist and explicitness, we can recommend music tailored to user demographics.
# This allows you to promote explicit music to users who typically listen to it (like "KEVVO" and "J Balvin") and recommend cleaner versions for others (e.g., parents looking for music for their children).
#
# 3. Optimizing content acquisition:
#
# We can analyze features like danceability and duration to understand user preferences for high-energy, shorter songs or slower, longer pieces.
# This can inform music licensing or content creation strategies. If users favor high-energy music ("Rock Anthem for Saving the World"), acquiring licensing rights for more such songs might be beneficial.
#
# 4. Improving Exploration vs Exploitation:
#
# We can leverage classification to balance familiar recommendations (songs similar to what a user likes) with exploration (introducing new genres or artists).
# This can be achieved by analyzing features alongside user listening history. For users who primarily listen to artists like "Los Caminantes" (low danceability), introduce some moderately high-energy recommendations to encourage exploration.
#
# 5. Exploiting Temporal Trends:
#
# We can analyze historical data to identify seasonal or time-based trends in music preferences.
# Classify songs by release date and popularity to understand seasonal variations.
# Recommend trending music or nostalgic throwbacks based on the time of year.

# %%
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation
import scipy.stats as sps # For Probability & Inferential Statistics
import time
import psutil
from google.colab import files
import io
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit
# Cross Validation
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv("/content/drive/MyDrive/df_merge.csv");df
# Out:
#                             id  cluster_number  valence  year  acousticness  \
# 0       7HmnJHfs0BkFzX4x8j0hkl               0   0.6420  2020      0.132000
# 1       1FCD2k9X5GHnVNLqY3T2NJ               0   0.3410  2002      0.000737
# 2       2JU0upXVRxdci09oNevxnJ               0   0.9700  1998      0.094500
# 3       74nsOZqzZzyvFVvBy12I7Y               0   0.5810  1998      0.376000
# 4       0P2fgmJp3a3PEu808hiQ1Y               0   0.8080  2002      0.014500
# ...                        ...             ...      ...   ...           ...
# 170648  26wJ64Pgts69F81vy1FHyu               2   0.4750  1992      0.000005
# 170649  2stzPKoUdtHcA4LlEu2ayw               2   0.3110  1992      0.016300
# 170650  4gsOR9hEmZqJF8BSLKuHUA               2   0.4140  2008      0.038800
# 170651  4ZpFsSsRdkSv0zqLREubUD               2   0.9610  1992      0.667000
# 170652  4BJqT0PrAfrxzMOxytFOIz               2   0.0594  1921      0.982000
#
# ...

# %%
# Resetting index to 'id' column
df1 = df.set_index('id')

# %%
df.columns
# Out:
# Index(['id', 'cluster_number', 'valence', 'year', 'acousticness', 'artists',
#        'danceability', 'duration_ms', 'energy', 'explicit', 'instrumentalness',
#        'key', 'liveness', 'loudness', 'mode', 'name', 'popularity',
#        'release_date', 'speechiness', 'tempo'],
#       dtype='object')

# %%
df_new = df1.drop(['artists','name','release_date','year'],axis = 1)

# %%
df_cat = df_new[['cluster_number','explicit','key','mode']] # Categorical Data [Nominal | Ordinal]
df_noncat = df_new[['valence', 'acousticness','danceability','duration_ms','energy','instrumentalness','liveness','loudness','popularity','speechiness','tempo']] # Non-Categorical Data

# %%
for i in df_cat:
  count_stats = pd.concat([df_cat[i].value_counts(), df_cat[i].value_counts(normalize=True).mul(100).round(0)], axis=1, keys=('count','percentage')).reset_index()
  print(i," : \n ",count_stats,"\n")
# Out:
# cluster_number  :
#      cluster_number  count  percentage
# 0               1  60606        36.0
# 1               0  58907        35.0
# 2               2  51140        30.0
#
# explicit  :
#      explicit   count  percentage
# 0         0  156220        92.0
# 1         1   14433         8.0
#
# key  :
#       key  count  percentage
# 0     0  21600        13.0
# 1     7  20803        12.0
# 2     2  18823        11.0
# 3     9  17571        10.0
# 4     5  16430        10.0
# 5     4  12933         8.0
# 6     1  12886         8.0
# 7    10  12148         7.0
# 8     8  10751         6.0
# 9    11  10670         6.0
# 10    6   8741         5.0
# 11    3   7297         4.0
#
# mode  :
#      mode   count  percentage
# 0     1  120635        71.0
# 1     0   50018        29.0

# %%
import matplotlib.pyplot as plt

# Determine the number of rows and columns for the subplot grid
num_rows = 2  # Two rows for four variables
num_cols = 2  # Two columns for four variables

# Create a subplot grid
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(14, 10))

# Flatten axes for easier iteration
axes = axes.flatten()

# Iterate over each categorical variable
for i, column in enumerate(df_cat.columns):
    # Calculate value counts for the current column
    value_counts = df_cat[column].value_counts()

    # Create a pie chart on the corresponding subplot
    ax = axes[i]
    ax.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
    ax.set_title(f"Pie Chart of {column}")
    ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Adjust layout and spacing
plt.tight_layout()
plt.show()

# %%
df_noncat.describe()
# Out:
#              valence   acousticness   danceability   duration_ms  \
# count  170653.000000  170653.000000  170653.000000  1.706530e+05
# mean        0.528587       0.502115       0.537396  2.309483e+05
# std         0.263171       0.376032       0.176138  1.261184e+05
# min         0.000000       0.000000       0.000000  5.108000e+03
# 25%         0.317000       0.102000       0.415000  1.698270e+05
# 50%         0.540000       0.516000       0.548000  2.074670e+05
# 75%         0.747000       0.893000       0.668000  2.624000e+05
# max         1.000000       0.996000       0.988000  5.403500e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  170653.000000     170653.000000  170653.000000  170653.000000
# mean        0.482389          0.167010       0.205839     -11.467990
# std         0.267646          0.313475       0.174805       5.697943
# min         0.000000          0.000000       0.000000     -60.000000
# ...

# %%
for i in df_noncat:
    # Calculate the standard deviation of each column
    std1 = round(np.std(df_noncat[i]), 2)
    print(f"Standard deviation of'{i}': {std1}")
# Out:
# Standard deviation of'valence': 0.26
# Standard deviation of'acousticness': 0.38
# Standard deviation of'danceability': 0.18
# Standard deviation of'duration_ms': 126118.05
# Standard deviation of'energy': 0.27
# Standard deviation of'instrumentalness': 0.31
# Standard deviation of'liveness': 0.17
# Standard deviation of'loudness': 5.7
# Standard deviation of'popularity': 21.83
# Standard deviation of'speechiness': 0.16
# Standard deviation of'tempo': 30.71

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sps

cols = df_noncat.columns
# Initialize an empty DataFrame to store p-values
p_values_df = pd.DataFrame(index=cols, columns=cols)

# Iterate over each pair of columns
for col1 in cols:
    for col2 in cols:
        # Skip if the columns are the same or if any of them is non-numeric
        if col1 == col2 or not (df_noncat[col1].dtype == 'float64' and df_noncat[col2].dtype == 'float64'):
            continue

        # Drop rows with NaN values in both columns
        filtered_df = df_noncat[[col1, col2]].dropna()

        # Perform Pearson correlation test
        _, p_value = sps.pearsonr(filtered_df[col1], filtered_df[col2])

        # Store the p-value in the DataFrame
        p_values_df.loc[col1, col2] = p_value

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(p_values_df.astype(float), annot=True, cmap='coolwarm', fmt=".3f", cbar_kws={'label': 'p-value'})
plt.title('Heatmap of Pearson Correlation P-values')
plt.xlabel('Variable')
plt.ylabel('Variable')
plt.show()

# %%
df_new.info() # Dataframe Information (Provide Information on Missing Data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170653 entries, 7HmnJHfs0BkFzX4x8j0hkl to 4BJqT0PrAfrxzMOxytFOIz
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   cluster_number    170653 non-null  int64
#  1   valence           170653 non-null  float64
#  2   acousticness      170653 non-null  float64
#  3   danceability      170653 non-null  float64
#  4   duration_ms       170653 non-null  int64
#  5   energy            170653 non-null  float64
#  6   explicit          170653 non-null  int64
#  7   instrumentalness  170653 non-null  float64
#  8   key               170653 non-null  int64
#  9   liveness          170653 non-null  float64
#  10  loudness          170653 non-null  float64
#  11  mode              170653 non-null  int64
#  12  popularity        170653 non-null  int64
#  13  speechiness       170653 non-null  float64
#  14  tempo             170653 non-null  float64
# ...

# %%
variable_missing_data = df_cat.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# cluster_number    0
# explicit          0
# key               0
# mode              0
# dtype: int64

# %%
variable_missing_data = df_noncat.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# valence             0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# liveness            0
# loudness            0
# popularity          0
# speechiness         0
# tempo               0
# dtype: int64

# %%
record_missing_data = df_new.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
# Out:
# id
# 7HmnJHfs0BkFzX4x8j0hkl    0
# 15CatBJBZlCFWkZSXbwzzy    0
# 5vh8YxbqEmXicPqkSTmwhA    0
# 2Fom6AIwPsRd76evrN3fRk    0
# 1GTaUP70Ids04tgLoRxiph    0
# dtype: int64

# %%
df_cat_mdt_code = df_cat.copy()
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
# Create DataFrame with index and column names
df_cat_code_oe = pd.DataFrame(oe_fit, index=df_cat_mdt_code.index, columns=df_cat_mdt_code.columns)
#df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True); df_cat_mdt_code_oe
# Out:
#                         cluster_number_x  explicit_x  key_x  mode_x  \
# id
# 7HmnJHfs0BkFzX4x8j0hkl                 0           1      7       1
# 1FCD2k9X5GHnVNLqY3T2NJ                 0           0      6       0
# 2JU0upXVRxdci09oNevxnJ                 0           0      7       1
# 74nsOZqzZzyvFVvBy12I7Y                 0           0      7       1
# 0P2fgmJp3a3PEu808hiQ1Y                 0           0      4       1
# ...                                  ...         ...    ...     ...
# 26wJ64Pgts69F81vy1FHyu                 2           0     11       1
# 2stzPKoUdtHcA4LlEu2ayw                 2           0     10       1
# 4gsOR9hEmZqJF8BSLKuHUA                 2           0     11       1
# 4ZpFsSsRdkSv0zqLREubUD                 2           0     10       0
# 4BJqT0PrAfrxzMOxytFOIz                 2           0     10       1
#
#                         cluster_number_y  explicit_y  key_y  mode_y
# id
# 7HmnJHfs0BkFzX4x8j0hkl               0.0         1.0    7.0     1.0
# ...

# %%
# Assuming df_noncat is your DataFrame containing the specified columns
columns = ['valence', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness']

# Creating box plots for each column
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")
sns.boxplot(data=df_noncat[columns], orient="h", palette="Set2")
plt.title("Box Plot of Various Audio Features")
plt.xlabel("Value")
plt.show()

# %%
columns = [ 'loudness', 'popularity','tempo']

# Creating box plots for each column
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")
sns.boxplot(data=df_noncat[columns], orient="h", palette="Set2")
plt.title("Box Plot of Various Audio Features")
plt.xlabel("Value")
plt.show()

# %%
columns = ['duration_ms']

# Creating box plots for each column
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")
sns.boxplot(data=df_noncat[columns], orient="h", palette="Set2")
plt.title("Box Plot of Various Audio Features")
plt.xlabel("Value")
plt.show()

# %%
df_noncat_mdt= df_noncat[['danceability', 'instrumentalness', 'liveness', 'speechiness','loudness', 'popularity','tempo','duration_ms']].copy()

# %%
# 3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat_mdt)
df_noncat_minmax_norm = pd.DataFrame(mms_fit,index=df_cat_mdt_code.index,columns=df_noncat_mdt.columns+'_mn'); df_noncat_minmax_norm
df_noncat_mdt_mmn = pd.merge(df_noncat, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn
# Out:
#                         valence  acousticness  danceability  duration_ms  \
# id
# 7HmnJHfs0BkFzX4x8j0hkl   0.6420      0.132000         0.856       189507
# 1FCD2k9X5GHnVNLqY3T2NJ   0.3410      0.000737         0.605        78347
# 2JU0upXVRxdci09oNevxnJ   0.9700      0.094500         0.719       230093
# 74nsOZqzZzyvFVvBy12I7Y   0.5810      0.376000         0.760       267093
# 0P2fgmJp3a3PEu808hiQ1Y   0.8080      0.014500         0.659       272267
# ...                         ...           ...           ...          ...
# 26wJ64Pgts69F81vy1FHyu   0.4750      0.000005         0.316       103253
# 2stzPKoUdtHcA4LlEu2ayw   0.3110      0.016300         0.426       353160
# 4gsOR9hEmZqJF8BSLKuHUA   0.4140      0.038800         0.535       253653
# 4ZpFsSsRdkSv0zqLREubUD   0.9610      0.667000         0.785       128547
# 4BJqT0PrAfrxzMOxytFOIz   0.0594      0.982000         0.279       831667
#
#                         energy  instrumentalness  liveness  loudness  \
# id
# ...

# %%
# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset
# Out:
#                         cluster_number_x  explicit_x  key_x  mode_x  \
# id
# 7HmnJHfs0BkFzX4x8j0hkl                 0           1      7       1
# 1FCD2k9X5GHnVNLqY3T2NJ                 0           0      6       0
# 2JU0upXVRxdci09oNevxnJ                 0           0      7       1
# 74nsOZqzZzyvFVvBy12I7Y                 0           0      7       1
# 0P2fgmJp3a3PEu808hiQ1Y                 0           0      4       1
# ...                                  ...         ...    ...     ...
# 26wJ64Pgts69F81vy1FHyu                 2           0     11       1
# 2stzPKoUdtHcA4LlEu2ayw                 2           0     10       1
# 4gsOR9hEmZqJF8BSLKuHUA                 2           0     11       1
# 4ZpFsSsRdkSv0zqLREubUD                 2           0     10       0
# 4BJqT0PrAfrxzMOxytFOIz                 2           0     10       1
#
#                         cluster_number_y  explicit_y  key_y  mode_y
# id
# 7HmnJHfs0BkFzX4x8j0hkl               0.0         1.0    7.0     1.0
# ...

# %%
# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd # Preferred Data Subset
# Out:
#                         valence  acousticness  danceability  duration_ms  \
# id
# 7HmnJHfs0BkFzX4x8j0hkl   0.6420      0.132000         0.856       189507
# 1FCD2k9X5GHnVNLqY3T2NJ   0.3410      0.000737         0.605        78347
# 2JU0upXVRxdci09oNevxnJ   0.9700      0.094500         0.719       230093
# 74nsOZqzZzyvFVvBy12I7Y   0.5810      0.376000         0.760       267093
# 0P2fgmJp3a3PEu808hiQ1Y   0.8080      0.014500         0.659       272267
# ...                         ...           ...           ...          ...
# 26wJ64Pgts69F81vy1FHyu   0.4750      0.000005         0.316       103253
# 2stzPKoUdtHcA4LlEu2ayw   0.3110      0.016300         0.426       353160
# 4gsOR9hEmZqJF8BSLKuHUA   0.4140      0.038800         0.535       253653
# 4ZpFsSsRdkSv0zqLREubUD   0.9610      0.667000         0.785       128547
# 4BJqT0PrAfrxzMOxytFOIz   0.0594      0.982000         0.279       831667
#
#                         energy  instrumentalness  liveness  loudness  \
# id
# ...

# %%
# Pre-Processed Dataset
df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd,left_index=True,right_index=True); df_ppd # Pre-Processed Dataset
# Out:
#                         cluster_number_x  explicit_x  key_x  mode_x  \
# id
# 7HmnJHfs0BkFzX4x8j0hkl                 0           1      7       1
# 1FCD2k9X5GHnVNLqY3T2NJ                 0           0      6       0
# 2JU0upXVRxdci09oNevxnJ                 0           0      7       1
# 74nsOZqzZzyvFVvBy12I7Y                 0           0      7       1
# 0P2fgmJp3a3PEu808hiQ1Y                 0           0      4       1
# ...                                  ...         ...    ...     ...
# 26wJ64Pgts69F81vy1FHyu                 2           0     11       1
# 2stzPKoUdtHcA4LlEu2ayw                 2           0     10       1
# 4gsOR9hEmZqJF8BSLKuHUA                 2           0     11       1
# 4ZpFsSsRdkSv0zqLREubUD                 2           0     10       0
# 4BJqT0PrAfrxzMOxytFOIz                 2           0     10       1
#
#                         cluster_number_y  explicit_y  key_y  mode_y  valence  \
# id
# ...

# %%
df_ppd.columns
# Out:
# Index(['cluster_number_x', 'explicit_x', 'key_x', 'mode_x', 'cluster_number_y',
#        'explicit_y', 'key_y', 'mode_y', 'valence', 'acousticness',
#        'danceability', 'duration_ms', 'energy', 'instrumentalness', 'liveness',
#        'loudness', 'popularity', 'speechiness', 'tempo', 'danceability_mn',
#        'instrumentalness_mn', 'liveness_mn', 'speechiness_mn', 'loudness_mn',
#        'popularity_mn', 'tempo_mn', 'duration_ms_mn'],
#       dtype='object')

# %%
df_ppd_updated=df_ppd.drop(['explicit_x', 'key_x', 'mode_x', 'cluster_number_y', 'danceability',
                            'instrumentalness', 'liveness','loudness', 'popularity','speechiness','tempo','duration_ms'], axis=1)

# %%
df_ppd_updated
# Out:
#                         cluster_number_x  explicit_y  key_y  mode_y  valence  \
# id
# 7HmnJHfs0BkFzX4x8j0hkl                 0         1.0    7.0     1.0   0.6420
# 1FCD2k9X5GHnVNLqY3T2NJ                 0         0.0    6.0     0.0   0.3410
# 2JU0upXVRxdci09oNevxnJ                 0         0.0    7.0     1.0   0.9700
# 74nsOZqzZzyvFVvBy12I7Y                 0         0.0    7.0     1.0   0.5810
# 0P2fgmJp3a3PEu808hiQ1Y                 0         0.0    4.0     1.0   0.8080
# ...                                  ...         ...    ...     ...      ...
# 26wJ64Pgts69F81vy1FHyu                 2         0.0   11.0     1.0   0.4750
# 2stzPKoUdtHcA4LlEu2ayw                 2         0.0   10.0     1.0   0.3110
# 4gsOR9hEmZqJF8BSLKuHUA                 2         0.0   11.0     1.0   0.4140
# 4ZpFsSsRdkSv0zqLREubUD                 2         0.0   10.0     0.0   0.9610
# 4BJqT0PrAfrxzMOxytFOIz                 2         0.0   10.0     1.0   0.0594
#
# ...

# %%
df_ppd_updated.columns
# Out:
# Index(['cluster_number_x', 'explicit_y', 'key_y', 'mode_y', 'valence',
#        'acousticness', 'energy', 'danceability_mn', 'instrumentalness_mn',
#        'liveness_mn', 'speechiness_mn', 'loudness_mn', 'popularity_mn',
#        'tempo_mn', 'duration_ms_mn'],
#       dtype='object')

# %%
# Analysis Objective : Segment the Cars based on, for example : Mileage (mpg) & Horsepower (hp)
# subsee
# Subset mtcars based on Inputs as {mpg, hp, cyl, vs} & Output as {am}
music_inputs = df_ppd_updated[['explicit_y', 'mode_y', 'valence',
       'acousticness', 'energy', 'danceability_mn', 'instrumentalness_mn',
       'liveness_mn', 'speechiness_mn', 'loudness_mn', 'popularity_mn',
       'tempo_mn', 'duration_ms_mn']]; music_inputs
music_outputs=df_ppd_updated[['cluster_number_x']]; #music_outputs

# %%
music_inputs_names = music_inputs.columns; music_inputs_names
music_outputs_labels = music_outputs['cluster_number_x'].unique().astype(str); music_outputs_labels
# Out:
# array(['0', '1', '2'], dtype='<U21')

# %%
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45044)
# Perform the stratified split to get training and testing indices
for i, j in stratified_split.split(music_inputs, music_outputs):
    train_music_inputs, test_music_inputs = music_inputs.iloc[i], music_inputs.iloc[j]
    train_music_outputs, test_music_outputs = music_outputs.iloc[i], music_outputs.iloc[j]

# %% [markdown]
# #Decision Tree

# %%
def memory_usage():
    """
    Function to get memory usage.
    """
    process = psutil.Process()
    mem = process.memory_info().rss
    return mem / (1024 * 1024)  # Convert to MB

# %%
#start time
start_dt = time.time()
# Measure memory usage
memory_before_dt = memory_usage()

# %%
# Decision Tree : Model (Training Subset)
dtc = DecisionTreeClassifier(criterion='gini', random_state=45044,max_depth=3) # Other Criteria : Entropy,  Log Loss
dtc_model = dtc.fit(train_music_inputs, train_music_outputs); dtc_model
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=45044)

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(music_inputs_names)); print(dtc_model_rules)
# Out:
# |--- mode_y <= 0.50
# |   |--- acousticness <= 0.48
# |   |   |--- speechiness_mn <= 0.92
# |   |   |   |--- class: 2
# |   |   |--- speechiness_mn >  0.92
# |   |   |   |--- class: 2
# |   |--- acousticness >  0.48
# |   |   |--- speechiness_mn <= 0.87
# |   |   |   |--- class: 0
# |   |   |--- speechiness_mn >  0.87
# |   |   |   |--- class: 2
# |--- mode_y >  0.50
# |   |--- explicit_y <= 0.50
# |   |   |--- duration_ms_mn <= 0.04
# |   |   |   |--- class: 1
# |   |   |--- duration_ms_mn >  0.04
# |   |   |   |--- class: 1
# |   |--- explicit_y >  0.50
# |   |   |--- loudness_mn <= 0.72
# |   |   |   |--- class: 1
# |   |   |--- loudness_mn >  0.72
# |   |   |   |--- class: 1

# %% [markdown]
# #Decision Tree Model Rule:
#
# The tree starts by splitting the data based on the mode_y feature, which likely represents a binary mode indicator (e.g., major or minor key).
# 1. If mode_y is less than or equal to 0.50, the left branch is taken; otherwise, the right branch is followed.
# Left Branch (mode_y <= 0.50):
#
#   1.1 If the acousticness feature is less than or equal to 0.48, further splitting occurs based on the speechiness_mn feature:
#
#   1.1.1 If speechiness_mn is less than or equal to 0.92, the class is assigned as 2 (likely representing the Dynamic and Expressive cluster):
#
#   1.1.2 If speechiness_mn is greater than 0.92, the class is assigned as 2.
#
#
#    1.2. If the acousticness feature is greater than 0.48, further splitting occurs based on the speechiness_mn feature:
#
#   1.2.1 If speechiness_mn is less than or equal to 0.87, the class is assigned as 0 (likely representing the Versatile and Balanced cluster).
#
#   1.2.2 If speechiness_mn is greater than 0.87, the class is assigned as 2.
#
#
# 2. Right Branch (mode_y > 0.50):
#
#   2.1 If explicit_y is less than or equal to 0.50, further splitting occurs based on the duration_ms_mn feature.
#
#  2.1.1 If duration_ms_mn is less than or equal to 0.04, the class is assigned as 1 (likely representing the Energetic and Dynamic cluster).
#
#  2.1.2 If duration_ms_mn is greater than 0.04, the class is assigned as 1.
#
#  2.2 If explicit_y is greater than 0.50, further splitting occurs based on the loudness_mn feature.
#  2.2.1 If loudness_mn is less than or equal to 0.72, the class is assigned as 1.
#
#  2.2.2 If loudness_mn is greater than 0.72, the class is assigned as 1.

# %%
# Decision Tree : Feature Importance
dtc_imp_features = pd.DataFrame({'feature': music_inputs_names, 'importance': np.round(dtc_model.feature_importances_, 2)})
dtc_imp_features.sort_values('importance', ascending=False, inplace=True); dtc_imp_features
# Out:
#                 feature  importance
# 1                mode_y        0.62
# 3          acousticness        0.14
# 8        speechiness_mn        0.11
# 0            explicit_y        0.07
# 9           loudness_mn        0.03
# 12       duration_ms_mn        0.03
# 2               valence        0.00
# 4                energy        0.00
# 5       danceability_mn        0.00
# 6   instrumentalness_mn        0.00
# 7           liveness_mn        0.00
# 10        popularity_mn        0.00
# 11             tempo_mn        0.00

# %% [markdown]
# Variable or Feature Analysis
#
# List of relevant features:
#
# mode_y: This feature has the highest importance score of 0.62.
#
# acousticness: With an importance score of 0.14, this feature is also important but less so than the mode_y.
#
# speechiness_mn: This feature has an importance score of 0.11.
#
# explicit_y: This feature has an importance score of 0.11.
#
# loudness_mn	and duration_ms_mn: Both these features has an importance score of 0.03
#
#
# List of Non-relevant features:
#
# The initial analysis identified the musical key as a very influential factor (importance score of 1) in the model's recommendations.Due to high importance, we decided to remove the key feature -'key'.
#
# Our concern was overfitting. Overfitting occurs when a model becomes overly reliant on a single feature, in this case, the key, to make predictions. This dependence can hinder the model's ability to learn from other important aspects of the music, potentially leading to poor performance on new, unseen songs.
#
# valence, energy, danceability_mn,	instrumentalness_mn,	liveness_mn,	popularity_mn,	tempo_mn has 0 feature importance.

# %%
# Decision Tree : Model Prediction (Testing Subset)
dtc_model_predict_test = dtc_model.predict(test_music_inputs); dtc_model_predict_test
# Out:
# array([1, 1, 2, ..., 1, 2, 1])

# %%
# Decision Tree : Prediction Evaluation (Testing Subset)
dtc_predict_conf_mat = pd.DataFrame(confusion_matrix(test_music_outputs, dtc_model_predict_test));print(dtc_predict_conf_mat)
dtc_predict_perf = classification_report(test_music_outputs, dtc_model_predict_test);  print(dtc_predict_perf)
# Out:
#       0     1     2
# 0  1794  8051  1937
# 1  1454  9398  1269
# 2  1359  6667  2202
#               precision    recall  f1-score   support
#
#            0       0.39      0.15      0.22     11782
#            1       0.39      0.78      0.52     12121
#            2       0.41      0.22      0.28     10228
#
#     accuracy                           0.39     34131
#    macro avg       0.40      0.38      0.34     34131
# weighted avg       0.39      0.39      0.34     34131

# %% [markdown]
# Columns: Represent the categories the model predicted (recommended songs).
#
# For instance, in the first row (Actual Category 0):
# The model correctly recommended 1794 songs that belong to category 0.
# It incorrectly recommended 8051 songs as category 1 and 1937 songs as category
# 2.
#
# Accuracy: The overall accuracy of the model (39%) is moderate. It correctly recommended only 39% of the songs.
#
# Precision: This tells you the accuracy of the model's recommendations for each category.
#
# A precision of 0.39 for all categories indicates that out of all songs recommended, only around 39% were truly in the correct category based on the actual labels. There were many false positives (recommended but not truly belonging to the category).
#
# Recall: This tells you how well the model identified songs that belong to each actual category.
#
# A recall of 0.15 for category 0 means the model captured only 15% of all songs that actually belong to category 0. It missed many relevant songs (false negatives).
#
# Recall for category 1 (0.78) is significantly higher, suggesting the model did well at identifying songs in this category.
#
# Recall for category 2 (0.22) is also low, indicating the model missed many songs that truly belong to category 2.
#
# F1-score: This combines precision and recall into a single metric. A score closer to 1 indicates better performance. The F1-scores here are generally low, reflecting limitations in the model's ability to recommend across all categories.
#
# F1 score for category 1 is 0.22, category 2 is 0.52 and for category 3 is 0.28.
#
#
# Macro vs. Weighted Average:
#
# The macro-average treats all categories equally, showing a generally low performance (around 0.40).
# The weighted-average considers the number of songs in each category. It's similar to the macro-average here because the class distribution might be relatively balanced.

# %%
# Decision Tree : Plot [Training Subset]
train_subset_dtc_plot = plot_tree(dtc_model, feature_names=music_inputs_names, class_names=music_outputs_labels, rounded=True, filled=True, fontsize=8)
plt.show()

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(dtc_predict_conf_mat, annot=True, fmt='d', cmap='Paired')
# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %%
# end time
end_dt = time.time()
# Memory afterward
memory_after_dt = memory_usage()

# total time taken
print(f"Runtime of the program is {end_dt - start_dt}")
print("Memory usage difference:", memory_after_dt - memory_before_dt, "MB")
# Out:
# Runtime of the program is 81.31454253196716
# Memory usage difference: 20.453125 MB

# %% [markdown]
# #SVM

# %%
#start time
start_svm = time.time()
# Measure memory usage
memory_before_svm = memory_usage()

# %%
# Initialize the SVM classifier
svm_classifier = SVC(kernel='linear', random_state=45044)  # You can choose different kernels like 'linear', 'poly', 'sigmoid', etc.

# %%
# Train the SVM model on the training subset
svm_model = svm_classifier.fit(train_music_inputs, train_music_outputs)
svm_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='linear', random_state=45044)

# %%
# Make predictions on the testing subset
svm_predict = svm_model.predict(test_music_inputs)
svm_predict
# Out:
# array([1, 1, 0, ..., 1, 0, 1])

# %%
# SVM : Prediction Evaluation (Testing Subset)
svm_predict_conf_mat = pd.DataFrame(confusion_matrix(test_music_outputs, svm_predict)); print(svm_predict_conf_mat)
svm_predict_perf = classification_report(test_music_outputs, svm_predict); print(svm_predict_perf)
# Out:
#       0     1    2
# 0  3627  8051  104
# 1  2634  9398   89
# 2  3345  6667  216
#               precision    recall  f1-score   support
#
#            0       0.38      0.31      0.34     11782
#            1       0.39      0.78      0.52     12121
#            2       0.53      0.02      0.04     10228
#
#     accuracy                           0.39     34131
#    macro avg       0.43      0.37      0.30     34131
# weighted avg       0.43      0.39      0.31     34131

# %% [markdown]
# # SVM
# Columns (0, 1, 2): Represent the categories the model predicted (recommended songs).
# For instance, in the first row (Actual Category 0):
# The model correctly recommended 3627 songs that belong to category 0.
# It incorrectly recommended 8051 songs as category 1 and 104 songs as category 2.
# Precision, Recall, F1-Score, Support: These metrics evaluate the model's performance.
#
# Precision:
#
# This tells you the accuracy of the model's recommendations for each category.
#
# A precision of 0.38 for category 0 means that out of all songs recommended as category 0, only 38% were truly category 0 based on the actual labels. There were many false positives (recommended as 0 but actually 1 or 2).
# Precision for category 1 (0.39) is similar, and precision for category 2 (0.53) is higher, but they all indicate some misclassifications.
#
# Recall:
#
# This tells you how well the model identified songs that belong to each actual category.
#
# A recall of 0.31 for category 0 means the model captured only 31% of all songs that actually belong to category 0. It missed many relevant songs (false negatives).
# Recall for category 1 (0.78) is significantly higher, suggesting the model did well at identifying songs in this category.
# However, the recall for category 2 (0.02) is very low, indicating the model rarely recommended songs that truly belong to category 2.
#
# F1-score:
#
# This combines precision and recall into a single metric. A score closer to 1 indicates better performance. The F1-scores here are generally low, reflecting limitations in the model's ability to recommend across all categories.
#
# Accuracy:
#
# The overall accuracy of the model (39%) is moderate. It correctly recommended only 39% of the songs.
#
# Macro vs. Weighted Average:
#
# The macro-average treats all categories equally, showing a generally low performance (around 0.43).
# The weighted-average considers the number of songs in each category. It's similar to the macro-average here because the class distribution might be relatively balanced.

# %%
# Confusion Matrix : Plot [Testing Subset]
ax = plt.axes()
sns.heatmap(svm_predict_conf_mat, annot=True, cmap='Paired')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('SVM : Confusion Matrix')
plt.show()

# %%
# end time
end_dt = time.time()
# Memory afterward
memory_after_dt = memory_usage()

# total time taken
print(f"Runtime of the program is {end_dt - start_dt}")
print("Memory usage difference:", memory_after_dt - memory_before_dt, "MB")
# Out:
# Runtime of the program is 1666.6551585197449
# Memory usage difference: 260.95703125 MB

# %% [markdown]
# #KNN

# %%
#start time
start_knn = time.time()
# Measure memory usage
memory_before_knn = memory_usage()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
# Initialize and fit the KNN classifier
n=5
knn_classifier = KNeighborsClassifier(n_neighbors=n)  # Adjust n_neighbors as needed
knn_classifier.fit(train_music_inputs, train_music_outputs)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
# Make predictions on the test dataset
knn_predictions = knn_classifier.predict(test_music_inputs)

# %%
# KNN : Prediction Evaluation (Testing Subset)
knn_predict_conf_mat = pd.DataFrame(confusion_matrix(test_music_outputs, knn_predictions)); print(knn_predict_conf_mat)
knn_predict_perf = classification_report(test_music_outputs,knn_predictions); print(knn_predict_perf)
# Out:
#       0     1     2
# 0  5860  3897  2025
# 1  5291  4892  1938
# 2  4642  3395  2191
#               precision    recall  f1-score   support
#
#            0       0.37      0.50      0.43     11782
#            1       0.40      0.40      0.40     12121
#            2       0.36      0.21      0.27     10228
#
#     accuracy                           0.38     34131
#    macro avg       0.38      0.37      0.37     34131
# weighted avg       0.38      0.38      0.37     34131

# %% [markdown]
#  KNN
#
# when n_neighbours = 5
#
# Accuracy : The KNN model demonstrates an accuracy of 38%.
#
# Precision :
#
# This tells you the accuracy of the model's predictions for each class level.
#
# A precision of 0.37 for class 0 means that out of all instances predicted as 0, only 37% were truly category 0 based on actual labels. There were many false positives (predicted 0 but actually 1 or 2).
# Precision for class 1 (0.40) and 2 (0.36) is slightly better, but still indicates misclassifications.
#
# The macro-average precision of 0.38 suggests a pretty bad model's predictions, considering all classes equally.
#
# Recall :
#
# The macro-average recall of 0.37 indicates the model's ability to capture true positive instances across all classes, giving equal weight to each class. It is representing not awesome but that will work.
#
# The weighted-average recall of 0.56 suggests a slightly better recall compared to the macro-average, considering the distribution of instances in each class.
#
# This tells you how well the model identified severity of each class for music recommendation.
#
# A recall of 0.50 for class 0 means the model captured 50% of all actual instances where the music or song recommended.
#
# The macro-average recall of 0.37 while the weighted average is 0.38.
#
#
# F1-score :
#
# The macro-average F1-score of 0.37 that their is a room for improvement.
#
# The weighted-average F1-score of 0.37 ,suggests a similar performance of the model in predicting music recommendation categories.
#
# As the number of neighbors (n_neighbours) increases, the accuracy was as follows:
#
# When k=7, the accuracy is 0.37.
#
# When k=9, the accuracy improves to 0.37.
#
# At k=11, the accuracy reach 0.38.
#
# Subsequently, at k=13 and k=15, the accuracy went to 0.37
#
# Macro vs. Weighted Average:
#
# The macro-average treats all severity levels equally, showing a generally low performance (around 0.38).
# The weighted-average considers the number of earthquakes in each category. It's similar to the macro-average here because the class distribution might be relatively balanced.

# %%
# Confusion Matrix : Plot [Testing Subset]
ax = plt.axes()
sns.heatmap(knn_predict_conf_mat, annot=True, cmap='Paired')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('KNN : Confusion Matrix')
plt.show()

# %%
# end time
end_knn = time.time()
# Memory afterward
memory_after_knn = memory_usage()

# total time taken
print(f"Runtime of the program is {end_knn - start_knn}")
print("Memory usage difference:", memory_after_knn - memory_before_knn, "MB")
# Out:
# Runtime of the program is 75.11660265922546
# Memory usage difference: 0.0 MB

# %%
k_values = [7, 9, 11, 13, 15]
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(train_music_inputs, train_music_outputs)  # Use your training data here
    y_pred = knn.predict(test_music_inputs)  # Use your testing data here
    accuracy = accuracy_score(test_music_outputs,y_pred)  # Compare predictions with true labels
    print(f'Accuracy for k={k}: {accuracy}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=7: 0.3785708007383317
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=9: 0.3790102839061264
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=11: 0.38158858515718846
# ...

# %%
#start time
start_lr = time.time()
# Measure memory usage
memory_before_lr = memory_usage()

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Creating and training the logistic regression model
logistic_regression = LogisticRegression()
logistic_regression.fit(train_music_inputs, train_music_outputs)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
# Making predictions on the test set
log_predictions = logistic_regression.predict(test_music_inputs)

# %%
# Logistic Regression : Prediction Evaluation (Testing Subset)
log_predict_conf_mat = pd.DataFrame(confusion_matrix(test_music_outputs, log_predictions)); print(log_predict_conf_mat)
log_predict_perf = classification_report(test_music_outputs,log_predictions); print(log_predict_perf)
# Out:
#       0     1     2
# 0  2973  7849   960
# 1  2273  9201   647
# 2  2488  6539  1201
#               precision    recall  f1-score   support
#
#            0       0.38      0.25      0.30     11782
#            1       0.39      0.76      0.52     12121
#            2       0.43      0.12      0.18     10228
#
#     accuracy                           0.39     34131
#    macro avg       0.40      0.38      0.33     34131
# weighted avg       0.40      0.39      0.34     34131

# %% [markdown]
# 3.2.4. Logistic Regression
#
# Accuracy : This is the overall accuracy of the model, meaning the percentage of instances it classified correctly across all categories. In this case, it's 39%.
#
# Precision :
#
# This tells us how many of the predictions the model made for a specific class (e.g., class 0) were actually correct.  For example, a precision of 0.38 for class 0 means out of all the instances the model predicted as class 0, only 38% were truly category 0 based on the actual labels, 39% for category 1 and 43% for category 2.
#
# The macro-average precision of 0.40 suggests a pretty bad model's predictions, considering all classes equally.
#
#
# Recall :
#
# This tells us how many of the actual instances in a specific class (e.g., class 0) did the model predict correctly. For instance, a recall of 0.25 for class 0 means out of all the actual class 0 instances, the model only predicted 25% of them correctly, class 1 predicted 76% correctly and class 2 predicted 12% correctly.
#
# The macro-average recall of 0.36 represents the pretty bad model.
#
# F1-Score
#
# This is a harmonic mean that combines precision and recall into a single metric. A score closer to 1 indicates better performance.
# The macro-average F1-score of 0.33 represents the pretty bad model. There is a need for improvement.
#
# The weighted-average F1-score of 0.34 representing an average score almost similar to macro average

# %%
# Confusion Matrix : Plot [Testing Subset]
ax = plt.axes()
sns.heatmap(log_predict_conf_mat, annot=True, cmap='Paired')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Logistic Regression : Confusion Matrix')
plt.show()

# %%
# end time
end_lr = time.time()
# Memory afterward
memory_after_lr = memory_usage()

# total time taken
print(f"Runtime of the program is {end_lr - start_lr}")
print("Memory usage difference:", memory_after_lr - memory_before_lr, "MB")
# Out:
# Runtime of the program is 39.91530442237854
# Memory usage difference: 4.15234375 MB

# %% [markdown]
# Results:
#
# ![image.png](data:image/png;base64,...)
#
# Overall Performance: All models have similar overall performance based on the macro-average metrics and accuracy. Their macro F1-scores range from 0.30 to 0.37, indicating a moderate ability to balance precision and recall across all categories. Their accuracy also falls within a narrow range (0.38 - 0.39).
#
# Macro F1-Score: The SVM model still has the highest macro F1-score (0.30), suggesting it might strike a slightly better balance between precision and recall on average.
#
# Accuracy and KNN: Interestingly, even though KNN has a similar macro F1-score to Decision Tree and Logistic Regression, its accuracy is slightly lower (0.38 compared to 0.39 for the others). This could indicate that KNN might be making more consistent but slightly less accurate predictions across categories.
#
# Similar Performance: Decision Tree, Logistic Regression, and KNN remain very close in terms of macro-average metrics and accuracy, making it difficult to definitively choose a winner without looking at individual class performance.
#
#
# List of Relevant features:
#
# mode_y, acousticness, speechiness_mn, explicit_y, loudness_mn and duration_ms_mn
#
# List of Non-relevant features: key
#
# Feature of 0 importance: valence, energy, danceability_mn, instrumentalness_mn, liveness_mn, popularity_mn, tempo_mn.
